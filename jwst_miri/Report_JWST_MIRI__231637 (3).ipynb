# %% [markdown]
# Firstly I installed the required libararies. AS follows:

# %%
# !pip install numpy matplotlib astropy
# !pip install regions

# %%
import numpy as np     #numpy for unit conversion and calculations
import matplotlib.pyplot as plt  #matplotlib to analyse in the form of graphs
from astropy.io import fits  #for astronomical units and astronomy plots
from matplotlib.colors import LogNorm  #to apply filters

import warnings
from astropy.wcs import WCS
from regions import Regions

from astropy import units as u

from astropy.wcs import WCS

from astropy.nddata.utils import extract_array

# %% [markdown]
# My next step is to open the fits file. So, for that I uploaded my files to drive and then link my collab to drive and copied the path in fits.open()

# %%
from astropy.io import fits  # Ensure fits is imported in this cell

CH_1_long = fits.open('/content/drive/MyDrive/Colab Notebooks/ISA Project /ISA/jw01328-c1006_t014_miri_ch1-long/jw01328-c1006_t014_miri_ch1-long_s3d.fits')
CH_1_medium = fits.open('/content/drive/MyDrive/Colab Notebooks/ISA Project /ISA/jw01328-c1006_t014_miri_ch1-medium/jw01328-c1006_t014_miri_ch1-medium_s3d.fits')
CH_1_short = fits.open('/content/drive/MyDrive/Colab Notebooks/ISA Project /ISA/jw01328-c1006_t014_miri_ch1-short/jw01328-c1006_t014_miri_ch1-short_s3d.fits')
# Assuming these are placeholders, I will remove the empty calls and duplicates.
# You can fill in the correct paths later.
CH_2_long = fits.open('/content/drive/MyDrive/Colab Notebooks/ISA Project /ISA/jw01328-c1006_t014_miri_ch2-long/jw01328-c1006_t014_miri_ch2-long_s3d.fits')
CH_2_medium  = fits.open('/content/drive/MyDrive/Colab Notebooks/ISA Project /ISA/jw01328-c1006_t014_miri_ch2-medium/jw01328-c1006_t014_miri_ch2-medium_s3d.fits')
CH_2_short = fits.open('/content/drive/MyDrive/Colab Notebooks/ISA Project /ISA/jw01328-c1006_t014_miri_ch2-short/jw01328-c1006_t014_miri_ch2-short_s3d.fits') # Duplicate

CH_3_long = fits.open('/content/drive/MyDrive/Colab Notebooks/ISA Project /ISA/jw01328-c1006_t014_miri_ch3-long/jw01328-c1006_t014_miri_ch3-long_s3d.fits')
CH_3_medium = fits.open('/content/drive/MyDrive/Colab Notebooks/ISA Project /ISA/jw01328-c1006_t014_miri_ch3-medium/jw01328-c1006_t014_miri_ch3-medium_s3d.fits')
CH_3_short = fits.open('/content/drive/MyDrive/Colab Notebooks/ISA Project /ISA/jw01328-c1006_t014_miri_ch3-short/jw01328-c1006_t014_miri_ch3-short_s3d.fits') # Duplicate

CH_4_long = fits.open('/content/drive/MyDrive/Colab Notebooks/ISA Project /ISA/jw01328-c1006_t014_miri_ch4-long/jw01328-c1006_t014_miri_ch4-long_s3d.fits')
CH_4_medium  = fits.open('/content/drive/MyDrive/Colab Notebooks/ISA Project /ISA/jw01328-c1006_t014_miri_ch4-medium/jw01328-c1006_t014_miri_ch4-medium_s3d.fits')
CH_4_short = fits.open('/content/drive/MyDrive/Colab Notebooks/ISA Project /ISA/jw01328-c1006_t014_miri_ch4-short/jw01328-c1006_t014_miri_ch4-short_s3d.fits') # Duplicate

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Open the SCI extension header from the FITS file (DS9 or python).**
#
#  Opened the header of the fits file by x.info():

# %%
print("\033[31mCH 1 LONG HEADER:\033[0m")
a_info = CH_1_long.info()
print("\033[31mCH 1 MEDIUM HEADER:\033[0m")
b_info = CH_1_medium.info()
print("\033[31mCH 1 SHORT HEADER:\033[0m")
c_info = CH_1_short.info()

print("\033[31mCH 2 LONG HEADER:\033[0m")
a_info = CH_2_long.info()
print("\033[31mCH 2 MEDIUM HEADER:\033[0m")
b_info = CH_2_medium.info()
print("\033[31mCH 2 SHORT HEADER:\033[0m")
c_info = CH_2_short.info()

print("\033[31mCH 3 LONG HEADER:\033[0m")
a_info = CH_3_long.info()
print("\033[31mCH 3 MEDIUM HEADER:\033[0m")
b_info = CH_3_medium.info()
print("\033[31mCH 3 SHORT HEADER:\033[0m")
c_info = CH_3_short.info()

print("\033[31mCH 4 LONG HEADER:\033[0m")
a_info = CH_4_long.info()
print("\033[31mCH 4 MEDIUM HEADER:\033[0m")
b_info = CH_4_medium.info()
print("\033[31mCH 4 SHORT HEADER:\033[0m")
c_info = CH_4_short.info()
# Out:
# CH 1 LONG HEADER:
# Filename: /content/drive/MyDrive/Colab Notebooks/ISA Project /ISA/jw01328-c1006_t014_miri_ch1-long/jw01328-c1006_t014_miri_ch1-long_s3d.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     373   ()
#   1  SCI           1 ImageHDU        89   (47, 43, 1400)   float32
#   2  ERR           1 ImageHDU        12   (47, 43, 1400)   float32
#   3  DQ            1 ImageHDU        12   (47, 43, 1400)   int32 (rescales to uint32)
#   4  WMAP          1 ImageHDU        10   (47, 43, 1400)   float32
# ...

# %%
print("\033[31mCH 1 LONG SCI HEADER:\033[0m")
CH_1_long[1].header
# Out:
# CH 1 LONG SCI HEADER:
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                  -32 / array data type
# NAXIS   =                    3 / number of array dimensions
# NAXIS1  =                   47
# NAXIS2  =                   43
# NAXIS3  =                 1400
# PCOUNT  =                    0 / number of parameters
# GCOUNT  =                    1 / number of groups
# EXTNAME = 'SCI     '           / extension name
# SRCTYPE = 'EXTENDED'           / Source type used for calibration
# MJD-BEG =    59764.18222700231 / [d] exposure start time in MJD
# MJD-AVG =   59764.186362702545 / [d] exposure mid-point in MJD
# MJD-END =    59764.19048210648 / [d] exposure end time in MJD
# TDB-BEG =    59764.18508149442 / [d] TDB time of exposure start in MJD
# TDB-MID =    59764.18921756051 / [d] TDB time of exposure mid-point in MJD
# TDB-END =   59764.193337328856 / [d] TDB time of exposure end in MJD
# XPOSURE =              444.008 / [s] Effective exposure time
# ...

# %%
print("\033[31mCH 1 MEDIUM SCI HEADER:\033[0m")
CH_1_medium[1].header
# Out:
# CH 1 MEDIUM SCI HEADER:
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                  -32 / array data type
# NAXIS   =                    3 / number of array dimensions
# NAXIS1  =                   47
# NAXIS2  =                   43
# NAXIS3  =                 1213
# PCOUNT  =                    0 / number of parameters
# GCOUNT  =                    1 / number of groups
# EXTNAME = 'SCI     '           / extension name
# SRCTYPE = 'EXTENDED'           / Source type used for calibration
# MJD-BEG =   59764.170504050926 / [d] exposure start time in MJD
# MJD-AVG =    59764.17467123264 / [d] exposure mid-point in MJD
# MJD-END =    59764.17885471065 / [d] exposure end time in MJD
# TDB-BEG =   59764.173357505926 / [d] TDB time of exposure start in MJD
# TDB-MID =   59764.177525056315 / [d] TDB time of exposure mid-point in MJD
# TDB-END =    59764.18170890442 / [d] TDB time of exposure end in MJD
# XPOSURE =              444.008 / [s] Effective exposure time
# ...

# %%
print("\033[31mCH 1 SHORT SCI HEADER:\033[0m")
CH_1_short[1].header
# Out:
# CH 1 SHORT SCI HEADER:
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                  -32 / array data type
# NAXIS   =                    3 / number of array dimensions
# NAXIS1  =                   47
# NAXIS2  =                   43
# NAXIS3  =                 1050
# PCOUNT  =                    0 / number of parameters
# GCOUNT  =                    1 / number of groups
# EXTNAME = 'SCI     '           / extension name
# SRCTYPE = 'EXTENDED'           / Source type used for calibration
# MJD-BEG =    59764.15884480324 / [d] exposure start time in MJD
# MJD-AVG =    59764.16312439236 / [d] exposure mid-point in MJD
# MJD-END =    59764.16738805555 / [d] exposure end time in MJD
# TDB-BEG =    59764.16169722669 / [d] TDB time of exposure start in MJD
# TDB-MID =   59764.165977194454 / [d] TDB time of exposure mid-point in MJD
# TDB-END =   59764.170241234875 / [d] TDB time of exposure end in MJD
# XPOSURE =              444.008 / [s] Effective exposure time
# ...

# %%
print("\033[31mCH 2 LONG SCI HEADER:\033[0m")
CH_2_long[1].header
# Out:
# CH 2 LONG SCI HEADER:
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                  -32 / array data type
# NAXIS   =                    3 / number of array dimensions
# NAXIS1  =                   43
# NAXIS2  =                   39
# NAXIS3  =                 1300
# PCOUNT  =                    0 / number of parameters
# GCOUNT  =                    1 / number of groups
# EXTNAME = 'SCI     '           / extension name
# SRCTYPE = 'EXTENDED'           / Source type used for calibration
# MJD-BEG =    59764.18222700231 / [d] exposure start time in MJD
# MJD-AVG =   59764.186362702545 / [d] exposure mid-point in MJD
# MJD-END =    59764.19048210648 / [d] exposure end time in MJD
# TDB-BEG =    59764.18508149442 / [d] TDB time of exposure start in MJD
# TDB-MID =    59764.18921756051 / [d] TDB time of exposure mid-point in MJD
# TDB-END =   59764.193337328856 / [d] TDB time of exposure end in MJD
# XPOSURE =              444.008 / [s] Effective exposure time
# ...

# %%
print("\033[31mCH 2 MEDIUM SCI HEADER:\033[0m")
CH_2_medium[1].header
# Out:
# CH 2 MEDIUM SCI HEADER:
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                  -32 / array data type
# NAXIS   =                    3 / number of array dimensions
# NAXIS1  =                   43
# NAXIS2  =                   39
# NAXIS3  =                 1124
# PCOUNT  =                    0 / number of parameters
# GCOUNT  =                    1 / number of groups
# EXTNAME = 'SCI     '           / extension name
# SRCTYPE = 'EXTENDED'           / Source type used for calibration
# MJD-BEG =   59764.170504050926 / [d] exposure start time in MJD
# MJD-AVG =    59764.17467123264 / [d] exposure mid-point in MJD
# MJD-END =    59764.17885471065 / [d] exposure end time in MJD
# TDB-BEG =   59764.173357505926 / [d] TDB time of exposure start in MJD
# TDB-MID =   59764.177525056315 / [d] TDB time of exposure mid-point in MJD
# TDB-END =    59764.18170890442 / [d] TDB time of exposure end in MJD
# XPOSURE =              444.008 / [s] Effective exposure time
# ...

# %%
print("\033[31mCH 2 SHORT SCI HEADER:\033[0m")
CH_2_short[1].header
# Out:
# CH 2 SHORT SCI HEADER:
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                  -32 / array data type
# NAXIS   =                    3 / number of array dimensions
# NAXIS1  =                   43
# NAXIS2  =                   39
# NAXIS3  =                  970
# PCOUNT  =                    0 / number of parameters
# GCOUNT  =                    1 / number of groups
# EXTNAME = 'SCI     '           / extension name
# SRCTYPE = 'EXTENDED'           / Source type used for calibration
# MJD-BEG =    59764.15884480324 / [d] exposure start time in MJD
# MJD-AVG =    59764.16312439236 / [d] exposure mid-point in MJD
# MJD-END =    59764.16738805555 / [d] exposure end time in MJD
# TDB-BEG =    59764.16169722669 / [d] TDB time of exposure start in MJD
# TDB-MID =   59764.165977194454 / [d] TDB time of exposure mid-point in MJD
# TDB-END =   59764.170241234875 / [d] TDB time of exposure end in MJD
# XPOSURE =              444.008 / [s] Effective exposure time
# ...

# %%
print("\033[31mCH 3 LONG SCI HEADER:\033[0m")
CH_3_long[1].header
# Out:
# CH 3 LONG SCI HEADER:
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                  -32 / array data type
# NAXIS   =                    3 / number of array dimensions
# NAXIS1  =                   47
# NAXIS2  =                   45
# NAXIS3  =                 1028
# PCOUNT  =                    0 / number of parameters
# GCOUNT  =                    1 / number of groups
# EXTNAME = 'SCI     '           / extension name
# SRCTYPE = 'EXTENDED'           / Source type used for calibration
# MJD-BEG =    59764.18222033565 / [d] exposure start time in MJD
# MJD-AVG =    59764.18635548033 / [d] exposure mid-point in MJD
# MJD-END =    59764.19047469908 / [d] exposure end time in MJD
# TDB-BEG =    59764.18507482717 / [d] TDB time of exposure start in MJD
# TDB-MID =   59764.189210337645 / [d] TDB time of exposure mid-point in MJD
# TDB-END =   59764.193329920796 / [d] TDB time of exposure end in MJD
# XPOSURE =              444.008 / [s] Effective exposure time
# ...

# %%
print("\033[31mCH 3 MEDIUM  SCI HEADER:\033[0m")
CH_3_medium[1].header
# Out:
# CH 3 MEDIUM  SCI HEADER:
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                  -32 / array data type
# NAXIS   =                    3 / number of array dimensions
# NAXIS1  =                   47
# NAXIS2  =                   45
# NAXIS3  =                  892
# PCOUNT  =                    0 / number of parameters
# GCOUNT  =                    1 / number of groups
# EXTNAME = 'SCI     '           / extension name
# SRCTYPE = 'EXTENDED'           / Source type used for calibration
# MJD-BEG =    59764.17049664352 / [d] exposure start time in MJD
# MJD-AVG =    59764.17466401042 / [d] exposure mid-point in MJD
# MJD-END =    59764.17884730324 / [d] exposure end time in MJD
# TDB-BEG =   59764.173350097866 / [d] TDB time of exposure start in MJD
# TDB-MID =    59764.17751783345 / [d] TDB time of exposure mid-point in MJD
# TDB-END =    59764.18170149636 / [d] TDB time of exposure end in MJD
# XPOSURE =              444.008 / [s] Effective exposure time
# ...

# %%
print("\033[31mCH 3 SHORT SCI HEADER:\033[0m")
CH_3_short[1].header
# Out:
# CH 3 SHORT SCI HEADER:
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                  -32 / array data type
# NAXIS   =                    3 / number of array dimensions
# NAXIS1  =                   47
# NAXIS2  =                   45
# NAXIS3  =                  769
# PCOUNT  =                    0 / number of parameters
# GCOUNT  =                    1 / number of groups
# EXTNAME = 'SCI     '           / extension name
# SRCTYPE = 'EXTENDED'           / Source type used for calibration
# MJD-BEG =    59764.15883739584 / [d] exposure start time in MJD
# MJD-AVG =    59764.16311698496 / [d] exposure mid-point in MJD
# MJD-END =    59764.16738064815 / [d] exposure end time in MJD
# TDB-BEG =    59764.16168981863 / [d] TDB time of exposure start in MJD
# TDB-MID =    59764.16596978638 / [d] TDB time of exposure mid-point in MJD
# TDB-END =   59764.170233826815 / [d] TDB time of exposure end in MJD
# XPOSURE =              444.008 / [s] Effective exposure time
# ...

# %%
print("\033[31mCH 4 LONG SCI HEADER:\033[0m")
CH_4_long[1].header
# Out:
# CH 4 LONG SCI HEADER:
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                  -32 / array data type
# NAXIS   =                    3 / number of array dimensions
# NAXIS1  =                   33
# NAXIS2  =                   33
# NAXIS3  =                  717
# PCOUNT  =                    0 / number of parameters
# GCOUNT  =                    1 / number of groups
# EXTNAME = 'SCI     '           / extension name
# SRCTYPE = 'EXTENDED'           / Source type used for calibration
# MJD-BEG =    59764.18222033565 / [d] exposure start time in MJD
# MJD-AVG =    59764.18635548033 / [d] exposure mid-point in MJD
# MJD-END =    59764.19047469908 / [d] exposure end time in MJD
# TDB-BEG =    59764.18507482717 / [d] TDB time of exposure start in MJD
# TDB-MID =   59764.189210337645 / [d] TDB time of exposure mid-point in MJD
# TDB-END =   59764.193329920796 / [d] TDB time of exposure end in MJD
# XPOSURE =              444.008 / [s] Effective exposure time
# ...

# %%
print("\033[31mCH 4 MEDIUM SCI HEADER:\033[0m")
CH_4_medium[1].header
# Out:
# CH 4 MEDIUM SCI HEADER:
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                  -32 / array data type
# NAXIS   =                    3 / number of array dimensions
# NAXIS1  =                   33
# NAXIS2  =                   33
# NAXIS3  =                  632
# PCOUNT  =                    0 / number of parameters
# GCOUNT  =                    1 / number of groups
# EXTNAME = 'SCI     '           / extension name
# SRCTYPE = 'EXTENDED'           / Source type used for calibration
# MJD-BEG =    59764.17049664352 / [d] exposure start time in MJD
# MJD-AVG =    59764.17466401042 / [d] exposure mid-point in MJD
# MJD-END =    59764.17884730324 / [d] exposure end time in MJD
# TDB-BEG =   59764.173350097866 / [d] TDB time of exposure start in MJD
# TDB-MID =    59764.17751783345 / [d] TDB time of exposure mid-point in MJD
# TDB-END =    59764.18170149636 / [d] TDB time of exposure end in MJD
# XPOSURE =              444.008 / [s] Effective exposure time
# ...

# %%
print("\033[31mCH 4 SHORT SCI HEADER:\033[0m")
CH_4_short[1].header
# Out:
# CH 4 SHORT SCI HEADER:
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                  -32 / array data type
# NAXIS   =                    3 / number of array dimensions
# NAXIS1  =                   33
# NAXIS2  =                   33
# NAXIS3  =                  542
# PCOUNT  =                    0 / number of parameters
# GCOUNT  =                    1 / number of groups
# EXTNAME = 'SCI     '           / extension name
# SRCTYPE = 'EXTENDED'           / Source type used for calibration
# MJD-BEG =    59764.15883739584 / [d] exposure start time in MJD
# MJD-AVG =    59764.16311698496 / [d] exposure mid-point in MJD
# MJD-END =    59764.16738064815 / [d] exposure end time in MJD
# TDB-BEG =    59764.16168981863 / [d] TDB time of exposure start in MJD
# TDB-MID =    59764.16596978638 / [d] TDB time of exposure mid-point in MJD
# TDB-END =   59764.170233826815 / [d] TDB time of exposure end in MJD
# XPOSURE =              444.008 / [s] Effective exposure time
# ...

# %% [markdown]
# **What is the pixel scale (CDELT1 or CDELT2) in arcseconds?**
#
# First i gave a variable to sci extension file and then grouped them in a library. Then i intiate the for loop for the cdelt1 and cdelt2 values in each variable by the .get function.

# %%
A1= CH_1_long[1].header
B1 = CH_1_medium[1].header
C1 = CH_1_short[1].header

A2= CH_2_long[1].header
B2 = CH_2_medium[1].header
C2 = CH_2_short[1].header

A3= CH_3_long[1].header
B3 = CH_3_medium[1].header
C3= CH_3_short[1].header

A4= CH_4_long[1].header
B4 = CH_4_medium[1].header
C4 = CH_4_short[1].header

# %%
headers = {
    "CH 1 long": A1,
    "CH 1 medium": B1,
    "CH 1 short": C1,
    "CH 2 long": A2,
    "CH 2 medium": B2,
    "CH 2 short": C2,
    "CH 3 long": A3,
    "CH 3 medium": B3,
    "CH 3 short": C3,
    "CH 4 long": A4,
    "CH 4 medium": B4,
    "CH 4 short": C4,
}

for channel_name, header in headers.items():
    print(f"\033[32m{channel_name}\033[0m")  # Green colored channel name

    cdelt1 = header.get('CDELT1', None)
    cdelt2 = header.get('CDELT2', None)

    print(f"CDELT1 of {channel_name.lower()}: {cdelt1} degrees/pixel")
    print(f"CDELT2 of {channel_name.lower()}: {cdelt2} degrees/pixel")
    print()  # Blank line for readability
# Out:
# CH 1 long
# CDELT1 of ch 1 long: 3.61111097865634e-05 degrees/pixel
# CDELT2 of ch 1 long: 3.61111097865634e-05 degrees/pixel
#
# CH 1 medium
# CDELT1 of ch 1 medium: 3.61111097865634e-05 degrees/pixel
# CDELT2 of ch 1 medium: 3.61111097865634e-05 degrees/pixel
#
# CH 1 short
# CDELT1 of ch 1 short: 3.61111097865634e-05 degrees/pixel
# CDELT2 of ch 1 short: 3.61111097865634e-05 degrees/pixel
#
# CH 2 long
# CDELT1 of ch 2 long: 4.72222227189275e-05 degrees/pixel
# CDELT2 of ch 2 long: 4.72222227189275e-05 degrees/pixel
#
# CH 2 medium
# CDELT1 of ch 2 medium: 4.72222227189275e-05 degrees/pixel
# CDELT2 of ch 2 medium: 4.72222227189275e-05 degrees/pixel
#
# CH 2 short
# CDELT1 of ch 2 short: 4.72222227189275e-05 degrees/pixel
# CDELT2 of ch 2 short: 4.72222227189275e-05 degrees/pixel
#
# CH 3 long
# CDELT1 of ch 3 long: 5.55555563833978e-05 degrees/pixel
# CDELT2 of ch 3 long: 5.55555563833978e-05 degrees/pixel
#
# CH 3 medium
# ...

# %% [markdown]
# To covert the values from degree/pixel to arcsec/pixel, I multiplied each value by 3600

# %%
cdelt_values = {
    "CH 1 long": 3.61111097865634e-05,
    "CH 1 medium": 3.61111097865634e-05,
    "CH 1 short": 3.61111097865634e-05,
    "CH 2 long": 4.72222227189275e-05,
    "CH 2 medium": 4.72222227189275e-05,
    "CH 2 short": 4.72222227189275e-05,
    "CH 3 long": 5.55555563833978e-05,
    "CH 3 medium": 5.55555563833978e-05,
    "CH 3 short": 5.55555563833978e-05,
    "CH 4 long": 9.72222205665376e-05,
    "CH 4 medium": 9.72222205665376e-05,
    "CH 4 short": 9.72222205665376e-05
}

print("\033[36mAngular resolution per pixel (arcsec/pixel):\033[0m")
for channel, cdelt_deg in cdelt_values.items():
    arcsec_per_pixel = cdelt_deg * 3600
    print(f"{channel}: {arcsec_per_pixel:.3f} arcsec/pixel")
# Out:
# Angular resolution per pixel (arcsec/pixel):
# CH 1 long: 0.130 arcsec/pixel
# CH 1 medium: 0.130 arcsec/pixel
# CH 1 short: 0.130 arcsec/pixel
# CH 2 long: 0.170 arcsec/pixel
# CH 2 medium: 0.170 arcsec/pixel
# CH 2 short: 0.170 arcsec/pixel
# CH 3 long: 0.200 arcsec/pixel
# CH 3 medium: 0.200 arcsec/pixel
# CH 3 short: 0.200 arcsec/pixel
# CH 4 long: 0.350 arcsec/pixel
# CH 4 medium: 0.350 arcsec/pixel
# CH 4 short: 0.350 arcsec/pixel

# %% [markdown]
# **Convert this value to parsecs per pixel using the astropy module**
#
# Formula for the conversion of parsec from arcsec is as follows:
#
# Size per pixel(parsecs)=D×( θ/206265)
#
#
#
# To convert arcseconds per pixel to parsecs per pixel, we should know the distance 'D' in parsec. without knowing the distance, I first convert arcseconds to radians, then use the small angle approximation to relate it to linear size.
#
# 1 arcsecond = (1/3600) degrees
#
# 1 degree = π / 180 radians
#
# Therefore, 1 arcsecond = (π / (180 * 3600)) radians.
#
# Let's denote the angular size in arcseconds as 'θ' and the equivalent in radians as 'α'. Then α = θ * (π / (180 * 3600)).

# %%
# Example: List of pixel scales in degrees per pixel (from your FITS headers CDELT1)
cdelt_values_deg = [
    3.61111097865634e-05,
    3.61111097865634e-05,
    3.61111097865634e-05,
    4.72222227189275e-05,
    4.72222227189275e-05,
    4.72222227189275e-05,
    5.55555563833978e-05,
    5.55555563833978e-05,
    5.55555563833978e-05,
    9.72222205665376e-05,
    9.72222205665376e-05,
    9.72222205665376e-05
]

channel_names = [
    "CH 1 long", "CH 1 medium", "CH 1 short",
    "CH 2 long", "CH 2 medium", "CH 2 short",
    "CH 3 long", "CH 3 medium", "CH 3 short",
    "CH 4 long", "CH 4 medium", "CH 4 short"
]

print("\033[36mAngular scale and symbolic parsecs per pixel:\033[0m")
for idx, cdelt_deg in enumerate(cdelt_values_deg):
    # Convert degrees per pixel to arcseconds per pixel
    pixel_scale_arcsec = (cdelt_deg * u.deg).to(u.arcsec)

    # Convert arcsec/pixel to radians per pixel
    pixel_scale_radian = pixel_scale_arcsec.to(u.radian)

    # Symbolic formula: Linear size per pixel = D * angular size in radians
    print(f"\033[32m{channel_names[idx]}\033[0m")
    print(f"Pixel scale: {pixel_scale_arcsec:.5f} arcsec/pixel")
    print(f"Radians per pixel: {pixel_scale_radian:.8e} rad/pixel")
    print(f"Linear scale per pixel: D × {pixel_scale_radian.value:.8e} parsecs per pixel (where D = distance in parsecs)")
    print()
# Out:
# Angular scale and symbolic parsecs per pixel:
# CH 1 long
# Pixel scale: 0.13000 arcsec arcsec/pixel
# Radians per pixel: 6.30257762e-07 rad rad/pixel
# Linear scale per pixel: D × 6.30257762e-07 parsecs per pixel (where D = distance in parsecs)
#
# CH 1 medium
# Pixel scale: 0.13000 arcsec arcsec/pixel
# Radians per pixel: 6.30257762e-07 rad rad/pixel
# Linear scale per pixel: D × 6.30257762e-07 parsecs per pixel (where D = distance in parsecs)
#
# CH 1 short
# Pixel scale: 0.13000 arcsec arcsec/pixel
# Radians per pixel: 6.30257762e-07 rad rad/pixel
# Linear scale per pixel: D × 6.30257762e-07 parsecs per pixel (where D = distance in parsecs)
#
# CH 2 long
# Pixel scale: 0.17000 arcsec arcsec/pixel
# Radians per pixel: 8.24183267e-07 rad rad/pixel
# Linear scale per pixel: D × 8.24183267e-07 parsecs per pixel (where D = distance in parsecs)
#
# CH 2 medium
# Pixel scale: 0.17000 arcsec arcsec/pixel
# Radians per pixel: 8.24183267e-07 rad rad/pixel
# ...

# %% [markdown]
# **Based on the typical pixel scale you computed for all channels, what
# physical size on the object does one pixel cover? Which region of the
# object are we trying to study here?**
#
# The image has a pixel size ranging from 0.13 to 0.35 arsec/pixel depending on the channel we use for measurment. each channel corresponds to different angular size in space.
#
# Given the high angular resolution (~0.13–0.35 arcsec/pixel) of these images, we are focusing on the central regions of NGC 7469, particularly the circumnuclear starburst ring and the active galactic nucleus (AGN).

# %% [markdown]
#                                       **Extract and Save Region Spectra:**

# %%
# Define the redshift for NGC 7469
# NGC 7469 is a Seyfert galaxy with a redshift of approximately 0.016268
# This value is used to convert observed wavelengths to rest-frame wavelengths
# The redshift value can be obtained from various astronomical databases like NED (NASA/IPAC Extragalactic Database)
import numpy as np
import warnings
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy.wcs import WCS
from regions import Regions

warnings.filterwarnings("ignore", category=UserWarning, append=True)
z = 0.016268

#reg_path = ("/content/drive/MyDrive/Colab Notebooks/ISA Project /ISA/Region/ch1_l") # From DS9 lecture, this is the region file containing the regions of interest
# Read the regions from the DS9 region file
# Make sure to have the regions file in the same directory as this script
#regions = Regions.read(reg_path, format='ds9')


#=================================================
from astropy.io import fits
from astropy.wcs import WCS
from astropy.coordinates import SkyCoord
from regions import CircleSkyRegion
import astropy.units as u
import numpy as np
import matplotlib.pyplot as plt

# Example region center (ICRS frame)
ra = 23.6208333 * u.degree    # RA in degrees
dec = 19.87305556 * u.degree     # Dec in degrees
radius_arcsec = 5 * u.arcsec    # Radius in arcseconds

center_icrs = SkyCoord(ra=ra, dec=dec, frame='icrs')
region_sky = CircleSkyRegion(center=center_icrs, radius=radius_arcsec)

# Loop over your cubes
for name, hdul in cubes.items():
    print(f"Processing: {name}")

    try:
        data_cube = hdul[1].data
        wcs = WCS(hdul[1].header)

        # Extract 2D spatial WCS (drop wavelength axis)
        wcs_2d = wcs.celestial

        # Convert region from sky to pixel coordinates
        region_pixel = region_sky.to_pixel(wcs_2d)

        # Prepare wavelength array (assuming spectral axis = 3rd axis in WCS)
        n_wave = data_cube.shape[0]
        wavelengths = []

        for i in range(n_wave):
            # Get world coordinates for pixel (x=0, y=0, z=i) to extract wavelength axis
            world = wcs.pixel_to_world(0, 0, i)
            wavelengths.append(world.spectral.to(u.micron).value)  # Convert wavelength to microns

        wavelengths = np.array(wavelengths)

        # Extract mean flux inside region per wavelength slice
        flux_spectrum = []

        for i in range(n_wave):
            slice_data = data_cube[i]
            mask = region_pixel.to_mask(mode='center')
            masked_data = mask.multiply(slice_data)
            mean_flux = np.nanmean(masked_data[~np.isnan(masked_data)])  # Mean flux in region
            flux_spectrum.append(mean_flux)

        flux_spectrum = np.array(flux_spectrum)

        # Plot the spectrum
        plt.figure(figsize=(10, 5))
        plt.plot(wavelengths, flux_spectrum, color='blue', label='Spectrum')
        plt.xlabel('Wavelength (microns)')
        plt.ylabel('Mean Flux (MJy/sr)')
        plt.title(f"Spectrum from {name} - Region: RA={ra.value}, Dec={dec.value}, Radius={radius_arcsec.value} arcsec (ICRS)")
        plt.legend()
        plt.grid(True)
        plt.show()

    except Exception as e:
        print(f"Error processing {name}: {e}")


#=================================================

file_paths = []

# Only channel 2 for the session
#for part in ['short','medium','long']:
        # I have kept them in a subfolder MAST_NGC_7469 for clarity
        # You can change the path as per your directory structure
        # The file names are based on the JWST data release naming convention
        #file_paths.append(f'/content/drive/MyDrive/Colab Notebooks/ISA Project /ISA/s3d/Copy of /jw01328-c1006_t014_miri_ch{2}-{part}_s3d.fits')
        #./MAST_NGC_7469/jw01328-c1006_t014_miri_ch{2}-{part}_s3d.fits

for ch_num in range(1,5):
    for part in ['short','medium','long']:
       file_paths.append(f'/content/drive/MyDrive/Colab Notebooks/ISA Project /ISA/s3d/Copy of /jw01328-c1006_t014_miri_ch{2}-{part}_s3d.fits')

print(file_paths)

# Loop over each region
# Initialize lists to store the spectrum and wavelength for all channels
spectrum_all = []
spectrum_all_err = []
wavelength_all = []

for region in regions:  # For now we are only considering one region. In your project you can loop over all regions

    for channel_index, file_path in enumerate(file_paths, start=1):

        # Initialize empty lists to store the spectrum and wavelength for this channel
        # This is done to store the spectrum and wavelength for each channel separately
        # This allows us to combine the spectra from all channels later
        spectrum = []
        spectrum_err = []

        # Get the mask for the region
        with fits.open(file_path) as hdul:
            data = hdul[1].data       # 1 contain the 3D data cube
            data[data < 0] = np.nan
            data_err = hdul[2].data   # 2 contain the error cube
            header = hdul[1].header

        # Open the FITS file and get the WCS information to make mask of the region
        # Mask means the region of interest in the image - other parts are ignored
        wcs = WCS(header)
        mask = region.to_pixel(wcs).to_mask()  # Convert the region from celestial to pixel coordinates then make a mask
        # Get the shape of the data
        num_channels, ny, nx = data.shape

        # Loop over each chan   nel (wavelength)
        for i in range(num_channels):
            # Extract the 2D image for the current channel
            masked_data = np.array(mask.multiply(data[i, :, :]), dtype=float)
            masked_data_err = np.array(mask.multiply(data_err[i, :, :]), dtype=float)

            avg_intensity = np.nanmean(masked_data)
            avg_intensity_err = np.sqrt(np.nanmean(masked_data_err**2))

            # Handle case where all values are NaN. To avoid RuntimeWarning: Mean of empty slice
            if np.isnan(avg_intensity):
                avg_intensity = 0
            if np.isnan(avg_intensity_err):
                avg_intensity_err = 0

            spectrum.append(avg_intensity)
            spectrum_err.append(avg_intensity_err)

        # Set up the wavelength axis
        n_wavelengths = data.shape[0]  # Number of wavelengths in the channel

        # Extract the WCS information from the header to get the wavelength values
        # CRVAL3, CDELT3, and CRPIX3 are WCS keywords that define the wavelength axis

        crval3 = header['CRVAL3']   # CRVAL3 is the reference value of the wavelength axis
        cdelt3 = header['CDELT3']   # CDELT3 is the increment in the wavelength axis
        crpix3 = header['CRPIX3']   # CRPIX3 is the reference pixel of the wavelength axis

        wavelength = (np.arange(n_wavelengths) - (crpix3 - 1)) * cdelt3 + crval3
        wavelength = wavelength / (1 + z) # Convert to rest-frame wavelength

        # Append the results for this channel to the overall lists
        # This is done to combine the spectra from all channels into one list
        # This allows us to plot the spectrum across all channels in one go
        # The wavelength and spectrum lists will have the same length

        wavelength_all.extend(wavelength)
        spectrum_all.extend(spectrum)
        spectrum_all_err.extend(spectrum_err)

        # Now you can add it to a dataframe. Explore pandas for this.
        # Since the instructions only require extracting the spectra,
        # I will not create a dataframe at this stage.
        # The extracted spectra are stored in wavelength_all, spectrum_all, and spectrum_all_err
# Out:
# Processing: Ch1_LONG
# Error processing Ch1_LONG: 'list' object has no attribute 'spectral'
# Processing: Ch1_MEDIUM
# Error processing Ch1_MEDIUM: 'list' object has no attribute 'spectral'
# Processing: Ch1_SHORT
# Error processing Ch1_SHORT: 'list' object has no attribute 'spectral'
# Processing: Ch2_LONG
# Error processing Ch2_LONG: 'list' object has no attribute 'spectral'
# Processing: Ch2_MEDIUM
# Error processing Ch2_MEDIUM: 'list' object has no attribute 'spectral'
# Processing: Ch2_SHORT
# Error processing Ch2_SHORT: 'list' object has no attribute 'spectral'
# Processing: Ch3_LONG
# Error processing Ch3_LONG: 'list' object has no attribute 'spectral'
# Processing: Ch3_MEDIUM
# Error processing Ch3_MEDIUM: 'list' object has no attribute 'spectral'
# Processing: Ch3_SHORT
# Error processing Ch3_SHORT: 'list' object has no attribute 'spectral'
# Processing: Ch4_LONG
# Error processing Ch4_LONG: 'list' object has no attribute 'spectral'
# Processing: Ch4_MEDIUM
# ...

# %%
# Loop over each region
# Initialize lists to store the spectrum and wavelength for all channels
spectrum_all = []
spectrum_all_err = []
wavelength_all = []

for region in regions:  # For now we are only considering one region. In your project you can loop over all regions

    for channel_index, file_path in enumerate(file_paths, start=1):

        # Initialize empty lists to store the spectrum and wavelength for this channel
        # This is done to store the spectrum and wavelength for each channel separately
        # This allows us to combine the spectra from all channels later
        spectrum = []
        spectrum_err = []

        # Get the mask for the region
        with fits.open(file_path) as hdul:
            data = hdul[1].data       # 1 contain the 3D data cube
            data[data < 0] = np.nan
            data_err = hdul[2].data   # 2 contain the error cube
            header = hdul[1].header

        # Open the FITS file and get the WCS information to make mask of the region
        # Mask means the region of interest in the image - other parts are ignored
        wcs = WCS(header)
        mask = region.to_pixel(wcs.celestial).to_mask()  # Convert the region from celestial to pixel coordinates then make a mask
        # Get the shape of the data
        num_channels, ny, nx = data.shape

        # Loop over each chan   nel (wavelength)
        for i in range(num_channels):
            # Extract the 2D image for the current channel
            masked_data = np.array(mask.multiply(data[i, :, :]), dtype=float)
            masked_data_err = np.array(mask.multiply(data_err[i, :, :]), dtype=float)

            avg_intensity = np.nanmean(masked_data)
            avg_intensity_err = np.sqrt(np.nanmean(masked_data_err**2))

            # Handle case where all values are NaN. To avoid RuntimeWarning: Mean of empty slice
            if np.isnan(avg_intensity):
                avg_intensity = 0
            if np.isnan(avg_intensity_err):
                avg_intensity_err = 0

            spectrum.append(avg_intensity)
            spectrum_err.append(avg_intensity_err)

        # Set up the wavelength axis
        n_wavelengths = data.shape[0]  # Number of wavelengths in the channel

        # Extract the WCS information from the header to get the wavelength values
        # CRVAL3, CDELT3, and CRPIX3 are WCS keywords that define the wavelength axis

        crval3 = header['CRVAL3']   # CRVAL3 is the reference value of the wavelength axis
        cdelt3 = header['CDELT3']   # CDELT3 is the increment in the wavelength axis
        crpix3 = header['CRPIX3']   # CRPIX3 is the reference pixel of the wavelength axis

        wavelength = (np.arange(n_wavelengths) - (crpix3 - 1)) * cdelt3 + crval3
        wavelength = wavelength / (1 + z) # Convert to rest-frame wavelength

        # Append the results for this channel to the overall lists
        # This is done to combine the spectra from all channels into one list
        # This allows us to plot the spectrum across all channels in one go
        # The wavelength and spectrum lists will have the same length

        wavelength_all.extend(wavelength)
        spectrum_all.extend(spectrum)
        spectrum_all_err.extend(spectrum_err)

        # Now you can add it to a dataframe. Explore pandas for this.
        # Since the instructions only require extracting the spectra,
        # I will not create a dataframe at this stage.
        # The extracted spectra are stored in wavelength_all, spectrum_all, and spectrum_all_err

# %%
for region in regions:  # also changed 'regions' to 'region' in the loop variable for clarity
    for channel_index, file_path in enumerate(files_path, start=1):
        spectrum = []
        spectrum_err = []

        data = fits.open(file_path)[1].data
        data[data < 0] = np.nan
        data_err = fits.open(file_path)[2].data

        header = fits.open(file_path)[1].header
        wcs = WCS(header)
        mask = region.to_pixel(wcs.celestial).to_mask()  # assuming each region is one region

        num_channels, ny, nx = data.shape

        for i in range(num_channels):
            masked_data = np.array(mask.multiply(data[i, :, :]), dtype=float)
            masked_data_err = np.array(mask.multiply(data_err[i, :, :]), dtype=float)

            avg_intensity = np.nanmean(masked_data)
            avg_intensity_err = np.sqrt(np.nanmean(masked_data_err**2))

            if np.isnan(avg_intensity):
                avg_intensity = 0
            if np.isnan(avg_intensity_err):
                avg_intensity_err = 0

            spectrum.append(avg_intensity)
            spectrum_err.append(avg_intensity_err)

        n_wavelengths = data.shape[0]

        crval = header['CRVAL1']
        crpix = header['CRPIX1']
        cdelt = header['CDELT1']

        wavelength = (np.arange(n_wavelengths) - (crpix - 1)) * cdelt + crval
        wavelength = wavelength * (1 + Z)

        wavelength_all.extend(wavelength)
        spectrum_all.extend(spectrum)
        spectrum_all_err.extend(spectrum_err)

# %%
plt.figure(figsize=(15, 8))
# Convert lists to numpy arrays for boolean indexing
wavelength_all_np = np.array(wavelength_all)
spectrum_all_np = np.array(spectrum_all)
spectrum_all_err_np = np.array(spectrum_all_err)

plt.errorbar(wavelength_all_np, spectrum_all_np, yerr=spectrum_all_err_np, color='blue', ecolor='black', label='Spectrum')
plt.xlabel('Wavelength (microns)')
plt.ylabel('Average Intensity (MJy/sr)')

# Change the x-axis limits to focus on the desired region
# w_start, w_end = 8.95, 9.05
# plt.xlim(w_start, w_end)

# Auto-scale y-axis to the visible range
# plt.ylim(0, 1.1*np.nanmax(spectrum_all_np[(wavelength_all_np >= w_start) & (wavelength_all_np <= w_end)]))
plt.grid(True)
plt.legend()

# %% [markdown]
# I tried multiple ways to solve this issue, but it seems it is not working
# i also use approach to make region using python. if ds9 has some issue.

# %%
# %pip install plotly

# %%
import plotly.graph_objects as go
import numpy as np

# Initialize figure with custom size
fig = go.Figure(layout=dict(
    width=800,  # Width in pixels
    height=500,  # Height in pixels
    template='plotly_white'
))

# Add spectrum trace
fig.add_trace(go.Scatter(
    x=wavelength_all,
    y=spectrum_all,
    mode='lines',
    line=dict(color='#1f77b4', width=1.5),
    name='Spectrum',
    hovertemplate='λ: %{x:.3f} μm<br>Intensity: %{y:.2f} MJy/sr<extra></extra>'
))

# Convert list to numpy
spectrum_all = np.array(spectrum_all)
spectrum_all_err = np.array(spectrum_all_err)

# Convert wavelength list to numpy
wavelength_all = np.array(wavelength_all)

# Add error band
fig.add_trace(go.Scatter(
    x=np.concatenate([wavelength_all, wavelength_all[::-1]]),
    y=np.concatenate([spectrum_all + spectrum_all_err,
                     (spectrum_all - spectrum_all_err)[::-1]]),
    fill='toself',
    fillcolor='rgba(31, 119, 180, 0.2)',
        line=dict(color='rgba(255,255,255,0)'),
    hoverinfo='skip',
    name='Uncertainty'
))

# Define all spectral features with different categories (edit here)
features = {
    'PAHs': {
         'PAH 7.7': 7.7, 'PAH 8.6': 8.6, 'PAH 11.3': 11.3,
    },
    'Iron': {

    },
    'Neon': {
         '[Ne VI]': 7.65,
    },
    'Other': {
         '[Ar III]': 8.991,
        '[S IV]': 10.51
    },
    'H₂': {
         'S(3)': 9.66,
        'S(4)': 8.03
    }
}

# Add all features with different colors and styles
colors = {
    'PAHs': '#FF7F0E',  # Orange
    'Iron': '#2CA02C',  # Green
    'Neon': '#D62728',  # Red
    'Other': '#9467BD',  # Purple
    'H₂': '#8C564B'     # Brown

}

# Add vertical lines and annotations
for category, lines in features.items():
    for name, wl in lines.items():
        fig.add_vline(
            x=wl,
            line=dict(
                color=colors[category],
                width=1.5 if category == 'PAHs' else 1,
                dash='dot' if category != 'PAHs' else 'solid'
            ),
            annotation=dict(
                text=name,
                yanchor='bottom',
                font=dict(
                    size=10,
                    color=colors[category]
                ),
                yshift=10 if category == 'PAHs' else 0
            )
        )

# Highlight PAH bands with shaded regions
for wl in [ 7.7, 8.6, 11.3]:  # Add the PAH bands you want to highlight
    # Add a shaded rectangle for each PAH band
    # The rectangle is centered around the wavelength with a width of 0.3 microns
    fig.add_vrect(
        x0=wl-0.15, x1=wl+0.15,
        fillcolor=colors['PAHs'],
        opacity=0.1,
        line_width=0
    )
  # Customize layout
fig.update_layout(
    # Title and axis labels
    title='<b>NGC 7469 JWST/MIRI IFU Spectrum with Molecular and Atomic Features</b>',
    xaxis_title='<b>Wavelength (μm)</b>',
    yaxis_title='<b>Intensity (MJy/sr)</b>',
    hovermode='x unified',                    # Unified hover mode for better interaction
    legend=dict(                              # Position the legend outside the plot area
        orientation='h',
        yanchor='bottom',
        y=1.02,
        xanchor='right',
        x=1
    ),
    margin=dict(l=50, r=50, b=50, t=80),      # Adjust margins for better spacing
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
 # %pip install jdaviz

# %%
from astropy.io import fits
import numpy as np
import matplotlib.pyplot as plt

# Load your MIRI data cube FITS file
hdul = fits.open('/content/drive/MyDrive/Colab Notebooks/ISA Project /ISA/jw01328-c1006_t014_miri_ch1-long/jw01328-c1006_t014_miri_ch1-long_s3d.fits')
cube_data = hdul[1].data  # check correct extension, sometimes it's [0], [1], or [SCI]

# Example: Plot a single wavelength slice
slice_index = 10  # Change this index as needed
plt.imshow(cube_data[slice_index, :, :], origin='lower', cmap='inferno')
plt.colorbar(label='Flux')
plt.title(f'Slice at index {slice_index}')
plt.show()

# %%
import matplotlib.pyplot as plt

# Mapping your variable names into a dictionary for looped access
cubes = {
    'Ch1_LONG': CH_1_long,
    'Ch1_MEDIUM': CH_1_medium,
    'Ch1_SHORT': CH_1_short,
    'Ch2_LONG': CH_2_long,
    'Ch2_MEDIUM': CH_2_medium,
    'Ch2_SHORT': CH_2_short,
    'Ch3_LONG': CH_3_long,
    'Ch3_MEDIUM': CH_3_medium,
    'Ch3_SHORT': CH_3_short,
    'Ch4_LONG': CH_4_long,
    'Ch4_MEDIUM': CH_4_medium,
    'Ch4_SHORT': CH_4_short,
}

# Loop over each cube
for name, hdul in cubes.items():
    print(f"Processing {name}...")

    # Example: Get data from primary SCI extension (usually extension 1, but check your file)
    try:
        data = hdul[1].data  # Adjust if needed based on your FITS structure
        if data is not None:
            # Plot first wavelength slice
            plt.figure(figsize=(5, 5))
            plt.imshow(data[0], origin='lower', cmap='inferno')
            plt.title(f"{name} - Slice 0")
            plt.colorbar(label='Flux')
            plt.show()
        else:
            print(f"No data found in {name}.")
    except Exception as e:
        print(f"Error processing {name}: {e}")
# Out:
# Processing Ch1_LONG...
# Processing Ch1_MEDIUM...
# Processing Ch1_SHORT...
# Processing Ch2_LONG...
# Processing Ch2_MEDIUM...
# Processing Ch2_SHORT...
# Processing Ch3_LONG...
# Processing Ch3_MEDIUM...
# Processing Ch3_SHORT...
# Processing Ch4_LONG...
# Processing Ch4_MEDIUM...
# Processing Ch4_SHORT...
